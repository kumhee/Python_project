# %%
import pandas as pd

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'], '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'], '키' : [197, 184, 168, 187, 188, 202, 188, 190], '국어' : [90, 40, 80, 40, 15, 80, 55, 100], '영어' : [85, 35, 75, 60, 20, 100, 65, 85], '수학' : [100, 50, 70, 70, 10, 95, 45, 90], '과학' : [95, 55, 80, 75, 35, 85, 40, 95], '사회' : [85, 25, 75, 80, 10, 80, 35, 95], 'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

# %%
data
# Out:
# {'이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
#  '학교': ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
#  '키': [197, 184, 168, 187, 188, 202, 188, 190],
#  '국어': [90, 40, 80, 40, 15, 80, 55, 100],
#  '영어': [85, 35, 75, 60, 20, 100, 65, 85],
#  '수학': [100, 50, 70, 70, 10, 95, 45, 90],
#  '과학': [95, 55, 80, 75, 35, 85, 40, 95],
#  '사회': [85, 25, 75, 80, 10, 80, 35, 95],
#  'SW특기': ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']}

# %%
data['이름']
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
temp = df['이름']
temp, temp.shape, type(temp)
# Out:
# (0    채치수
#  1    정대만
#  2    송태섭
#  3    서태웅
#  4    강백호
#  5    변덕규
#  6    황태산
#  7    윤대협
#  Name: 이름, dtype: object,
#  (8,),
#  pandas.core.series.Series)

# %%
temp = df[['이름', '키']]
temp, type(temp)
# Out:
# (    이름    키
#  0  채치수  197
#  1  정대만  184
#  2  송태섭  168
#  3  서태웅  187
#  4  강백호  188
#  5  변덕규  202
#  6  황태산  188
#  7  윤대협  190,
#  pandas.core.frame.DataFrame)

# %%
temp.shape
# Out:
# (8, 2)

# %%
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.DataFrame(data, columns=['이름', '학교', '키'])
df
# Out:
#     이름   학교    키
# 0  채치수  북산고  197
# 1  정대만  북산고  184
# 2  송태섭  북산고  168
# 3  서태웅  북산고  187
# 4  강백호  북산고  188
# 5  변덕규  능남고  202
# 6  황태산  능남고  188
# 7  윤대협  능남고  190

# %%
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.set_index('이름', inplace=True)
df
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_index()
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 서태웅  북산고  187   40   60   70  75  80
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 윤대협  능남고  190  100   85   90  95  95          C#
# 정대만  북산고  184   40   35   50  55  25        Java
# 채치수  북산고  197   90   85  100  95  85      Python
# 황태산  능남고  188   55   65   45  40  35      PYTHON

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 윤대협  능남고  190  100   85   90  95  95          C#
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 변덕규  능남고  202   80  100   95  85  80           C
# 강백호  북산고  188   15   20   10  35  10

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.to_csv('score.csv', encoding='utf-8-sig') #csv 파일 저장

# %%
df.to_csv('score.txt', sep='\t') #text 파일 저장 < \t 텍스트 사이에 띄어쓰기로 구분 >

# %%
df.to_excel('score.xlsx')

# %%
df = pd.read_csv('score.csv') # 저장한 파일 읽기

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df1 = pd.read_csv('시가총액.csv')

# %%
df1
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,000   2,000  +0.47%    500  1,010,880
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  710,000   2,000  -0.28%  2,500    505,335
# 4    5                삼성전자우   58,100     600  -1.02%    100    478,097
# 5    6             POSCO홀딩스  471,500   3,500  -0.74%  5,000    398,753
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  214,000   3,500  +1.66%    100    347,554
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  474,000   1,000  +0.21%  5,000    334,608
# 10  11                삼성SDI  443,000   3,500  +0.80%  5,000    304,627
# 11  12               포스코퓨처엠  338,000  10,000  -2.87%    500    261,826
# ...

# %%
df.describe()
# Out:
#                 키          국어          영어          수학         과학         사회
# count    8.000000    8.000000    8.000000    8.000000   8.000000   8.000000
# mean   188.000000   62.500000   65.625000   66.250000  70.000000  60.625000
# std      9.985704   29.519969   26.917533   30.325614  23.754699  32.120032
# min    168.000000   15.000000   20.000000   10.000000  35.000000  10.000000
# 25%    186.250000   40.000000   53.750000   48.750000  51.250000  32.500000
# 50%    188.000000   67.500000   70.000000   70.000000  77.500000  77.500000
# 75%    191.750000   82.500000   85.000000   91.250000  87.500000  81.250000
# max    202.000000  100.000000  100.000000  100.000000  95.000000  95.000000

# %%
df.head()
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85      Python
# 1   2번  정대만  북산고  184  40  35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80  75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187  40  60   70  75  80         NaN
# 4   5번  강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.head(1)
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85  Python

# %%
df.head(2)
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85  Python
# 1   2번  정대만  북산고  184  40  35   50  55  25    Java

# %%
df.tail()
# Out:
#   지원번호   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 3   4번  서태웅  북산고  187   40   60  70  75  80     NaN
# 4   5번  강백호  북산고  188   15   20  10  35  10     NaN
# 5   6번  변덕규  능남고  202   80  100  95  85  80       C
# 6   7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 7   8번  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.values
# Out:
# array([['1번', '채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'],
#        ['2번', '정대만', '북산고', 184, 40, 35, 50, 55, 25, 'Java'],
#        ['3번', '송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['4번', '서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['5번', '강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['6번', '변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C'],
#        ['7번', '황태산', '능남고', 188, 55, 65, 45, 40, 35, 'PYTHON'],
#        ['8번', '윤대협', '능남고', 190, 100, 85, 90, 95, 95, 'C#']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.columns
# Out:
# Index(['지원번호', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.shape
# Out:
# (8, 10)

# %%
df['키'].describe() # 통계
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].min(), df['키'].max()
# Out:
# (168, 202)

# %%
df['키'].nlargest(3) # 큰값 3개
# Out:
# 5    202
# 0    197
# 7    190
# Name: 키, dtype: int64

# %%
df['키'].mean() # 평균
# Out:
# 188.0

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'].count() # 빈 값은 count 하지 않음
# Out:
# 6

# %%
df['학교'].unique() # 중복을 제거하고 출력
# Out:
# array(['북산고', '능남고'], dtype=object)

# %%
df['학교'].nunique() # 중복을 제거한 값의 개수를 출력
# Out:
# 2

# %%
df['이름']
# Out:
# 0    채치수
# 1    정대만
# 2    송태섭
# 3    서태웅
# 4    강백호
# 5    변덕규
# 6    황태산
# 7    윤대협
# Name: 이름, dtype: object

# %%
df[['이름', '키']][:3]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168

# %%
df[3:]
# Out:
#   지원번호   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 3   4번  서태웅  북산고  187   40   60  70  75  80     NaN
# 4   5번  강백호  북산고  188   15   20  10  35  10     NaN
# 5   6번  변덕규  능남고  202   80  100  95  85  80       C
# 6   7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 7   8번  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df[:3]
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85      Python
# 1   2번  정대만  북산고  184  40  35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80  75   70  80  75  Javascript

# %%
df.loc[0] # 데이터 선택
# Out:
# 지원번호        1번
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 0, dtype: object

# %%
df = pd.read_csv('score.csv', index_col='지원번호') # index값 지정하기

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['1번','국어']
# Out:
# 90

# %%
temp = df.loc[['1번','2번'], '국어']
temp, type(temp)
# Out:
# (지원번호
#  1번    90
#  2번    40
#  Name: 국어, dtype: int64,
#  pandas.core.series.Series)

# %%
temp = df.loc[['1번', '2번'], ['국어', '영어']]
temp, type(temp)
# Out:
# (      국어  영어
#  지원번호
#  1번    90  85
#  2번    40  35,
#  pandas.core.frame.DataFrame)

# %%
df.iloc[0]
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.iloc[0:5]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.iloc[0,1]
# Out:
# '북산고'

# %%
df.iloc[[0,1],[0,1]]
# Out:
#        이름   학교
# 지원번호
# 1번    채치수  북산고
# 2번    정대만  북산고

# %%
df.iloc[0:2, 0:2]
# Out:
#        이름   학교
# 지원번호
# 1번    채치수  북산고
# 2번    정대만  북산고

# %%
df1 = pd.read_csv('시가총액.csv')

# %%
df1
# Out:
#      N                  종목명      현재가     전일비     등락률    액면가       시가총액  \
# 0    1                 삼성전자   71,600   1,000  -1.38%    100  4,274,364
# 1    2             LG에너지솔루션  432,000   2,000  +0.47%    500  1,010,880
# 2    3               SK하이닉스  126,600   4,500  -3.43%  5,000    921,651
# 3    4             삼성바이오로직스  710,000   2,000  -0.28%  2,500    505,335
# 4    5                삼성전자우   58,100     600  -1.02%    100    478,097
# 5    6             POSCO홀딩스  471,500   3,500  -0.74%  5,000    398,753
# 6    7                  현대차  181,000     600  -0.33%  5,000    382,872
# 7    8                NAVER  214,000   3,500  +1.66%    100    347,554
# 8    9                   기아   84,200     100  +0.12%  5,000    338,521
# 9   10                 LG화학  474,000   1,000  +0.21%  5,000    334,608
# 10  11                삼성SDI  443,000   3,500  +0.80%  5,000    304,627
# 11  12               포스코퓨처엠  338,000  10,000  -2.87%    500    261,826
# ...

# %%
filt = df['키'] >= 185
df[filt]
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85  Python
# 4번    서태웅  북산고  187   40   60   70  75  80     NaN
# 5번    강백호  북산고  188   15   20   10  35  10     NaN
# 6번    변덕규  능남고  202   80  100   95  85  80       C
# 7번    황태산  능남고  188   55   65   45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95      C#

# %%
df[~filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    정대만  북산고  184  40  35  50  55  25        Java
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
df.loc[df['키'] >= 185 , ['이름','국어','영어','수학']]
# Out:
#        이름   국어   영어   수학
# 지원번호
# 1번    채치수   90   85  100
# 4번    서태웅   40   60   70
# 5번    강백호   15   20   10
# 6번    변덕규   80  100   95
# 7번    황태산   55   65   45
# 8번    윤대협  100   85   90

# %%
df.loc[df['키'] <= 185 ]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    정대만  북산고  184  40  35  50  55  25        Java
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
filt = df['이름'].str.startswith('송') # 이름에 '송' 이 들어간 사람 출력
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
filt = df['이름'].str.contains('대')
df[filt]
# Out:
#        이름   학교    키   국어  영어  수학  과학  사회  SW특기
# 지원번호
# 2번    정대만  북산고  184   40  35  50  55  25  Java
# 8번    윤대협  능남고  190  100  85  90  95  95    C#

# %%
lans = ['Python', 'Java']
filt = df['SW특기'].isin(lans)
df[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85  Python
# 2번    정대만  북산고  184  40  35   50  55  25    Java

# %%
lans = ['python', 'java']
filt = df['SW특기'].str.lower.isin(lans) # 소문자로 변경해주면 검색 가능
df[filt]

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.fillna('')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.fillna('없음')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80          없음
# 5번    강백호  북산고  188   15   20   10  35  10          없음
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
import numpy as np
df['학교'] = np.nan
df
# Out:
#        이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수 NaN  197   90   85  100  95  85      Python
# 2번    정대만 NaN  184   40   35   50  55  25        Java
# 3번    송태섭 NaN  168   80   75   70  80  75  Javascript
# 4번    서태웅 NaN  187   40   60   70  75  80         NaN
# 5번    강백호 NaN  188   15   20   10  35  10         NaN
# 6번    변덕규 NaN  202   80  100   95  85  80           C
# 7번    황태산 NaN  188   55   65   45  40  35      PYTHON
# 8번    윤대협 NaN  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df2 = df
df2.dropna(inplace=True)
df2
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python  455
# 2번    정대만  북산고  184   40   35   50  55  25        Java  205
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript  380
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN  325
# 5번    강백호  북산고  188   15   20   10  35  10         NaN   90
# 6번    변덕규  능남고  202   80  100   95  85  80           C  440
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON  240
# 8번    윤대협  능남고  190  100   85   90  95  95          C#  465

# %%
df.loc[df['총합'] >= 400, '결과'] = 'Pass'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python  455  Pass
# 2번    정대만  북산고  184   40   35   50  55  25        Java  205   nan
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript  380   nan
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN  325   nan
# 5번    강백호  북산고  188   15   20   10  35  10         NaN   90   nan
# 6번    변덕규  능남고  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON  240   nan
# 8번    윤대협  능남고  190  100   85   90  95  95          C#  465  Pass

# %%
df.drop(columns=['총합'])
# Out:
#           이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번       채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번       정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번       송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번       서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번       강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번       변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번       황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번       윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번    해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
filt = df['수학'] < 80
df[filt].index
# Out:
# Index(['2번', '3번', '4번', '5번', '7번'], dtype='object', name='지원번호')

# %%
df.drop(index=df[filt].index)
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회    SW특기   총합    결과
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85  Python  455  Pass
# 6번    변덕규  능남고  202   80  100   95  85  80       C  440  Pass
# 8번    윤대협  능남고  190  100   85   90  95  95      C#  465  Pass

# %%
df.loc['9번'] = ['이정환', '해남고등학교', 184,90,90,90,90,90,'Kotlin', 450, 'Pass']

# %%
df
# Out:
#         결과      이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번    Pass     채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번     nan     정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번     nan     송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번     nan     서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번     nan     강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번    Pass     변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번     nan     황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번    Pass     윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번     이정환  해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
df['학교'] = df['학교'] + '등학교'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수     북산고등학교  197   90   85  100  95  85      Python  455  Pass
# 2번    정대만     북산고등학교  184   40   35   50  55  25        Java  205   nan
# 3번    송태섭     북산고등학교  168   80   75   70  80  75  Javascript  380   nan
# 4번    서태웅     북산고등학교  187   40   60   70  75  80         NaN  325   nan
# 5번    강백호     북산고등학교  188   15   20   10  35  10         NaN   90   nan
# 6번    변덕규     능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산     능남고등학교  188   55   65   45  40  35      PYTHON  240   nan
# 8번    윤대협     능남고등학교  190  100   85   90  95  95          C#  465  Pass
# 9번    이정환  해남고등하고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %%
df.loc['4번', 'SW특기'] = 'Python'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수     북산고등학교  197   90   85  100  95  85      Python  455  Pass
# 2번    정대만     북산고등학교  184   40   35   50  55  25        Java  205   nan
# 3번    송태섭     북산고등학교  168   80   75   70  80  75  Javascript  380   nan
# 4번    서태웅     북산고등학교  187   40   60   70  75  80      Python  325   nan
# 5번    강백호     북산고등학교  188   15   20   10  35  10         NaN   90   nan
# 6번    변덕규     능남고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산     능남고등학교  188   55   65   45  40  35      PYTHON  240   nan
# 8번    윤대협     능남고등학교  190  100   85   90  95  95          C#  465  Pass
# 9번    이정환  해남고등하고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %%
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합', '결과']

# %%
df = df[[cols[-1]] + cols[0:-1]]
df
# Out:
#         결과   이름         학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    Pass  채치수     북산고등학교  197   90   85  100  95  85      Python  455
# 2번     nan  정대만     북산고등학교  184   40   35   50  55  25        Java  205
# 3번     nan  송태섭     북산고등학교  168   80   75   70  80  75  Javascript  380
# 4번     nan  서태웅     북산고등학교  187   40   60   70  75  80      Python  325
# 5번     nan  강백호     북산고등학교  188   15   20   10  35  10         NaN   90
# 6번    Pass  변덕규     능남고등학교  202   80  100   95  85  80           C  440
# 7번     nan  황태산     능남고등학교  188   55   65   45  40  35      PYTHON  240
# 8번    Pass  윤대협     능남고등학교  190  100   85   90  95  95          C#  465
# 9번    Pass  이정환  해남고등하고등학교  184   90   90   90  90  90      Kotlin  450

# %%
df.drop(index='9번')
# Out:
#         결과   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    Pass  채치수  북산고등학교  197   90   85  100  95  85      Python  455
# 2번     nan  정대만  북산고등학교  184   40   35   50  55  25        Java  205
# 3번     nan  송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380
# 4번     nan  서태웅  북산고등학교  187   40   60   70  75  80      Python  325
# 5번     nan  강백호  북산고등학교  188   15   20   10  35  10         NaN   90
# 6번    Pass  변덕규  능남고등학교  202   80  100   95  85  80           C  440
# 7번     nan  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240
# 8번    Pass  윤대협  능남고등학교  190  100   85   90  95  95          C#  465

# %%
df
# Out:
#         결과      이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번    Pass     채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번     nan     정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번     nan     송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번     nan     서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번     nan     강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번    Pass     변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번     nan     황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번    Pass     윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번     이정환  해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
df.drop(columns=['결과'])
# Out:
#           이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번       채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번       정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번       송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번       서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번       강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번       변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번       황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번       윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번    해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\data\python\pandas\ex01.ipynb Cell 92 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/data/python/pandas/ex01.ipynb#Y160sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined

# %%
df.drop(index='8번')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\data\python\pandas\ex01.ipynb Cell 93 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/data/python/pandas/ex01.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> df.drop(index='8번')
#
# NameError: name 'df' is not defined

# %%
df.drop(columns=['결과'],inplace=True)
# Out:
# C:\Users\eu_un\AppData\Local\Temp\ipykernel_25212\30770651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['결과'],inplace=True)

# %%
df
# Out:
#           이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번       채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번       정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번       송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번       서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번       강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번       변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번       황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번       윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번    해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
df.drop(index='9번')
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수  북산고등학교  197   90   85  100  95  85      Python  455
# 2번    정대만  북산고등학교  184   40   35   50  55  25        Java  205
# 3번    송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380
# 4번    서태웅  북산고등학교  187   40   60   70  75  80      Python  325
# 5번    강백호  북산고등학교  188   15   20   10  35  10         NaN   90
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440
# 7번    황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465

# %%
df
# Out:
#           이름      학교    키   국어   영어   수학  과학      사회        SW특기    총합
# 지원번호
# 1번       채치수  북산고등학교  197   90   85  100  95      85      Python   455
# 2번       정대만  북산고등학교  184   40   35   50  55      25        Java   205
# 3번       송태섭  북산고등학교  168   80   75   70  80      75  Javascript   380
# 4번       서태웅  북산고등학교  187   40   60   70  75      80      Python   325
# 5번       강백호  북산고등학교  188   15   20   10  35      10         NaN    90
# 6번       변덕규  능남고등학교  202   80  100   95  85      80           C   440
# 7번       황태산  능남고등학교  188   55   65   45  40      35      PYTHON   240
# 8번       윤대협  능남고등학교  190  100   85   90  95      95          C#   465
# 9번    해남고등학교     184   90   90   90   90  90  Kotlin         450  Pass

# %%
df = pd.read_csv('score.csv', index_col='지원번호')

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
def add_cm(height):
    return str(height) + 'cm'

# %%
df['키'] = df['키'].apply(add_cm)

# %%
df
# Out:
#        이름   학교      키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197cm   90   85  100  95  85      Python
# 2번    정대만  북산고  184cm   40   35   50  55  25        Java
# 3번    송태섭  북산고  168cm   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187cm   40   60   70  75  80         NaN
# 5번    강백호  북산고  188cm   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202cm   80  100   95  85  80           C
# 7번    황태산  능남고  188cm   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190cm  100   85   90  95  95          C#

# %%
def capitalize(lang):
    if pd.notnull(lang):
        return lang.capitalize()
    return lang

# %%
df['SW특기'] = df['SW특기'].apply(capitalize)
df
# Out:
#        이름   학교      키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197cm   90   85  100  95  85      Python
# 2번    정대만  북산고  184cm   40   35   50  55  25        Java
# 3번    송태섭  북산고  168cm   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187cm   40   60   70  75  80         NaN
# 5번    강백호  북산고  188cm   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202cm   80  100   95  85  80           C
# 7번    황태산  능남고  188cm   55   65   45  40  35      Python
# 8번    윤대협  능남고  190cm  100   85   90  95  95          C#

# %%
df
# Out:
#        이름   학교      키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197cm   90   85  100  95  85      Python
# 2번    정대만  북산고  184cm   40   35   50  55  25        Java
# 3번    송태섭  북산고  168cm   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187cm   40   60   70  75  80         NaN
# 5번    강백호  북산고  188cm   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202cm   80  100   95  85  80           C
# 7번    황태산  능남고  188cm   55   65   45  40  35      Python
# 8번    윤대협  능남고  190cm  100   85   90  95  95          C#

# %%
df.groupby('학교').get_group('능남고')
# Out:
#        이름   학교      키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 6번    변덕규  능남고  202cm   80  100  95  85  80       C
# 7번    황태산  능남고  188cm   55   65  45  40  35  Python
# 8번    윤대협  능남고  190cm  100   85  90  95  95      C#

# %%
df.groupby('학교').size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
df.groupby('학교')['키'].mean()
# Out:
# 학교
# 능남고    193.333333
# 북산고    184.800000
# Name: 키, dtype: float64

# %%
df.groupby('학교')[['국어','영어','수학']].mean()
# Out:
#             국어         영어         수학
# 학교
# 능남고  78.333333  83.333333  76.666667
# 북산고  53.000000  55.000000  60.000000

# %%
df['학년'] = [3,3,3,1,1,3,2,2]
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python   3
# 2번    정대만  북산고  184   40   35   50  55  25        Java   3
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript   3
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN   1
# 5번    강백호  북산고  188   15   20   10  35  10         NaN   1
# 6번    변덕규  능남고  202   80  100   95  85  80           C   3
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON   2
# 8번    윤대협  능남고  190  100   85   90  95  95          C#   2

# %%
df.groupby(['학교', '학년'])[['국어','영어']].mean()
# Out:
#           국어     영어
# 학교  학년
# 능남고 2   77.5   75.0
#     3   80.0  100.0
# 북산고 1   27.5   40.0
#     3   70.0   65.0
